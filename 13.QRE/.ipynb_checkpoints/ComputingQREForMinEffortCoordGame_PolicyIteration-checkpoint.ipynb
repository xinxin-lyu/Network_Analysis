# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Consider a minimum-effort coordination game between $N=2$ players drawn from a population of agents. Each player $i$ has two actions: either exert high effort or exert low effort, $a_i∈\{H,L\}$. The high effort benefits players only if every player chooses the high-effort. If any player chooses the low-effort, then all players receive only the benefit from the low effort. Thus the payoffs are: $$p(a_i;a_{-i})=1+min_{j∈{1,…,n}}⁡ a_j-ca_i$$

# %% [markdown]
# # Part 1: Preliminaries

# %%
# CRRA utility function
def CRRA(x,gamma): #can use offset by xMin in case of negative values of x
    if gamma == 1:
        return np.log(x)
    else:
        return ((x)**(1-gamma) - 1)/(1-gamma)

# %%
# Calculate expected utility of action a given other players' mixing prob.
# Notice that I'm assuming each one has two actions available. 
def Utility(pOther,cost,gamma):
    n=len(pOther)
    pH=pOther[1]**n #Probability that all other play H
    u1 = pH*CRRA(1+min(1, 1) - cost*1,gamma) + \
        (1-pH)* CRRA(1+min(1, 0) - cost*1,gamma) #Add
    u0 = pH*CRRA(1+min(0, 1) - cost*0,gamma) + \
        (1-pH)* CRRA(1+min(0, 0) - cost*0,gamma) #Add  
    return np.array([u0, u1])

# %%
cost=.5
l=1
gamma=0
p0=np.array([.5,.5])

# %%
#Check utilities
Utility(p0,cost,gamma)
# Out:
# array([ 0.  , -0.25])

# %%
#Check probability calculation
np.exp(l*Utility(p0,cost,gamma))/np.sum(np.exp(l*Utility(p0,cost,gamma)))
# Out:
# array([0.5621765, 0.4378235])

# %% [markdown]
# ## Part 2: Compute QRE

# %% [markdown]
# Assumptions:
#     * Two agents
#     * Two actions
#     * Symmetry

# %%
#Define the function whose 0 we want to find
l=2
cost=.5
gamma=.5
p0=np.array([.5,.5])
diff=1
while diff>.0001:
    print("--------------------------------")
    print("Difference:",diff)
    print("Guess:",p0)
    print("Expected Utility:",Utility(p0,cost,gamma))
    p1=np.exp(l*Utility(p0,cost,gamma))/np.sum(np.exp(l*Utility(p0,cost,gamma)))
    print("New Policy:",p1)
    diff=np.sum(np.abs(p0-p1))
    p0=.9*p0+.1*p1
print("QRE: ",p1)
# Out:
# --------------------------------
# Difference: 1
# Guess: [0.5 0.5]
# Expected Utility: [ 0.         -0.32696739]
# New Policy: [0.65789661 0.34210339]
# --------------------------------
# Difference: 0.31579321777026825
# Guess: [0.51578966 0.48421034]
# Expected Utility: [ 0.         -0.34305594]
# New Policy: [0.66510144 0.33489856]
# --------------------------------
# Difference: 0.29862355727485507
# Guess: [0.53072084 0.46927916]
# Expected Utility: [ 0.         -0.35779488]
# New Policy: [0.67163512 0.32836488]
# --------------------------------
# Difference: 0.28182855253958067
# Guess: [0.54481227 0.45518773]
# Expected Utility: [ 0.         -0.37128149]
# New Policy: [0.67755605 0.32244395]
# --------------------------------
# Difference: 0.26548757349755525
# Guess: [0.55808665 0.44191335]
# Expected Utility: [ 0.         -0.38361003]
# New Policy: [0.68291923 0.31708077]
# --------------------------------
# Difference: 0.24966517081576783
# Guess: [0.5705699 0.4294301]
# Expected Utility: [ 0.         -0.39487094]
# New Policy: [0.68777591 0.31222409]
# --------------------------------
# Difference: 0.23441200372932558
# Guess: [0.5822905 0.4177095]
# Expected Utility: [ 0.         -0.40515018]
# New Policy: [0.69217351 0.30782649]
# --------------------------------
# Difference: 0.21976600624580156
# Guess: [0.5932788 0.4067212]
# Expected Utility: [ 0.         -0.41452885]
# New Policy: [0.69615565 0.30384435]
# --------------------------------
# Difference: 0.20575368516437442
# Guess: [0.60356649 0.39643351]
# Expected Utility: [ 0.         -0.42308292]
# New Policy: [0.69976222 0.30023778]
# --------------------------------
# Difference: 0.1923914675917932
# Guess: [0.61318606 0.38681394]
# Expected Utility: [ 0.         -0.43088322]
# New Policy: [0.70302958 0.29697042]
# --------------------------------
# Difference: 0.1796870370051979
# Guess: [0.62217041 0.37782959]
# Expected Utility: [ 0.         -0.43799538]
# New Policy: [0.70599072 0.29400928]
# --------------------------------
# Difference: 0.16764061487892717
# Guess: [0.63055244 0.36944756]
# Expected Utility: [ 0.         -0.44448004]
# New Policy: [0.70867552 0.29132448]
# --------------------------------
# Difference: 0.15624615943064457
# Guess: [0.63836475 0.36163525]
# Expected Utility: [ 0.         -0.45039296]
# New Policy: [0.71111098 0.28888902]
# --------------------------------
# Difference: 0.14549246441621255
# Guess: [0.64563938 0.35436062]
# Expected Utility: [ 0.        -0.4557853]
# New Policy: [0.71332145 0.28667855]
# --------------------------------
# Difference: 0.13536414952111792
# Guess: [0.65240758 0.34759242]
# Expected Utility: [ 0.         -0.46070386]
# New Policy: [0.71532885 0.28467115]
# --------------------------------
# Difference: 0.12584254021329339
# Guess: [0.65869971 0.34130029]
# Expected Utility: [ 0.         -0.46519137]
# New Policy: [0.71715293 0.28284707]
# --------------------------------
# Difference: 0.11690643937974454
# Guess: [0.66454503 0.33545497]
# Expected Utility: [ 0.         -0.46928677]
# New Policy: [0.71881143 0.28118857]
# --------------------------------
# Difference: 0.10853279606574645
# Guess: [0.66997167 0.33002833]
# Expected Utility: [ 0.        -0.4730255]
# New Policy: [0.72032031 0.27967969]
# --------------------------------
# Difference: 0.1006972785120438
# Guess: [0.67500654 0.32499346]
# Expected Utility: [ 0.         -0.47643979]
# New Policy: [0.72169392 0.27830608]
# --------------------------------
# Difference: 0.09337475972496684
# Guess: [0.67967527 0.32032473]
# Expected Utility: [ 0.         -0.47955889]
# New Policy: [0.72294514 0.27705486]
# --------------------------------
# Difference: 0.08653972424396889
# Guess: [0.68400226 0.31599774]
# Expected Utility: [ 0.         -0.48240938]
# New Policy: [0.72408556 0.27591444]
# --------------------------------
# Difference: 0.08016660476949683
# Guess: [0.68801059 0.31198941]
# Expected Utility: [ 0.         -0.48501535]
# New Policy: [0.72512562 0.27487438]
# --------------------------------
# Difference: 0.07423005701908875
# Guess: [0.69172209 0.30827791]
# Expected Utility: [ 0.         -0.48739869]
# New Policy: [0.72607468 0.27392532]
# --------------------------------
# Difference: 0.06870518069530701
# Guess: [0.69515735 0.30484265]
# Expected Utility: [ 0.         -0.48957922]
# New Policy: [0.7269412 0.2730588]
# --------------------------------
# Difference: 0.06356769385289579
# Guess: [0.69833574 0.30166426]
# Expected Utility: [ 0.         -0.49157493]
# New Policy: [0.72773277 0.27226723]
# --------------------------------
# Difference: 0.05879406730060949
# Guess: [0.70127544 0.29872456]
# Expected Utility: [ 0.         -0.49340216]
# New Policy: [0.72845625 0.27154375]
# --------------------------------
# Difference: 0.05436162500541969
# Guess: [0.70399352 0.29600648]
# Expected Utility: [ 0.         -0.49507571]
# New Policy: [0.72911783 0.27088217]
# --------------------------------
# Difference: 0.05024861581073681
# Guess: [0.70650595 0.29349405]
# Expected Utility: [ 0.         -0.49660904]
# New Policy: [0.72972308 0.27027692]
# --------------------------------
# Difference: 0.04643426115405819
# Guess: [0.70882767 0.29117233]
# Expected Utility: [ 0.         -0.49801435]
# New Policy: [0.73027706 0.26972294]
# --------------------------------
# Difference: 0.04289878288429155
# Guess: [0.7109726 0.2890274]
# Expected Utility: [ 0.         -0.49930274]
# New Policy: [0.73078431 0.26921569]
# --------------------------------
# Difference: 0.039623414741138396
# Guess: [0.71295378 0.28704622]
# Expected Utility: [ 0.        -0.5004843]
# New Policy: [0.73124898 0.26875102]
# --------------------------------
# Difference: 0.03659040057095425
# Guess: [0.7147833 0.2852167]
# Expected Utility: [ 0.        -0.5015682]
# New Policy: [0.73167479 0.26832521]
# --------------------------------
# Difference: 0.03378298191555562
# Guess: [0.71647244 0.28352756]
# Expected Utility: [ 0.         -0.50256279]
# New Policy: [0.73206513 0.26793487]
# --------------------------------
# Difference: 0.031185377220937616
# Guess: [0.71803171 0.28196829]
# Expected Utility: [ 0.         -0.50347565]
# New Policy: [0.73242309 0.26757691]
# --------------------------------
# Difference: 0.028782754569143643
# Guess: [0.71947085 0.28052915]
# Expected Utility: [ 0.         -0.50431372]
# New Policy: [0.73275145 0.26724855]
# --------------------------------
# Difference: 0.026561199535289015
# Guess: [0.72079891 0.27920109]
# Expected Utility: [ 0.        -0.5050833]
# New Policy: [0.73305275 0.26694725]
# --------------------------------
# Difference: 0.02450767950935956
# Guess: [0.72202429 0.27797571]
# Expected Utility: [ 0.         -0.50579014]
# New Policy: [0.7333293 0.2666707]
# --------------------------------
# Difference: 0.022610005595160743
# Guess: [0.7231548 0.2768452]
# Expected Utility: [ 0.         -0.50643949]
# New Policy: [0.73358319 0.26641681]
# --------------------------------
# Difference: 0.020856793003020124
# Guess: [0.72419763 0.27580237]
# Expected Utility: [ 0.         -0.50703614]
# New Policy: [0.73381635 0.26618365]
# --------------------------------
# Difference: 0.01923742068502221
# Guess: [0.72515951 0.27484049]
# Expected Utility: [ 0.         -0.50758447]
# New Policy: [0.7340305 0.2659695]
# --------------------------------
# Difference: 0.017741990818405995
# Guess: [0.72604661 0.27395339]
# Expected Utility: [ 0.         -0.50808848]
# New Policy: [0.73422725 0.26577275]
# --------------------------------
# Difference: 0.016361288621223102
# Guess: [0.72686467 0.27313533]
# Expected Utility: [ 0.         -0.50855182]
# New Policy: [0.73440804 0.26559196]
# --------------------------------
# Difference: 0.015086742881700865
# Guess: [0.72761901 0.27238099]
# Expected Utility: [ 0.         -0.50897784]
# New Policy: [0.7345742 0.2654258]
# --------------------------------
# Difference: 0.013910387496456733
# Guess: [0.72831453 0.27168547]
# Expected Utility: [ 0.        -0.5093696]
# New Policy: [0.73472694 0.26527306]
# --------------------------------
# Difference: 0.012824824240561195
# Guess: [0.72895577 0.27104423]
# Expected Utility: [ 0.        -0.5097299]
# New Policy: [0.73486736 0.26513264]
# --------------------------------
# Difference: 0.01182318693246237
# Guess: [0.72954693 0.27045307]
# Expected Utility: [ 0.        -0.5100613]
# New Policy: [0.73499648 0.26500352]
# --------------------------------
# Difference: 0.01089910710722547
# Guess: [0.73009188 0.26990812]
# Expected Utility: [ 0.         -0.51036616]
# New Policy: [0.73511522 0.26488478]
# --------------------------------
# Difference: 0.01004668127086078
# Guess: [0.73059422 0.26940578]
# Expected Utility: [ 0.         -0.51064663]
# New Policy: [0.73522444 0.26477556]
# --------------------------------
# Difference: 0.00926043977541563
# Guess: [0.73105724 0.26894276]
# Expected Utility: [ 0.         -0.51090469]
# New Policy: [0.7353249 0.2646751]
# --------------------------------
# Difference: 0.008535317327784175
# Guess: [0.731484 0.268516]
# Expected Utility: [ 0.         -0.51114216]
# New Policy: [0.73541732 0.26458268]
# --------------------------------
# Difference: 0.007866625123886473
# Guess: [0.73187734 0.26812266]
# Expected Utility: [ 0.         -0.51136068]
# New Policy: [0.73550235 0.26449765]
# --------------------------------
# Difference: 0.007250024583081327
# Guess: [0.73223984 0.26776016]
# Expected Utility: [ 0.         -0.51156179]
# New Policy: [0.73558059 0.26441941]
# --------------------------------
# Difference: 0.006681502644696025
# Guess: [0.73257391 0.26742609]
# Expected Utility: [ 0.         -0.51174689]
# New Policy: [0.73565259 0.26434741]
# --------------------------------
# Difference: 0.006157348578720301
# Guess: [0.73288178 0.26711822]
# Expected Utility: [ 0.         -0.51191726]
# New Policy: [0.73571885 0.26428115]
# --------------------------------
# Difference: 0.005674132255492292
# Guess: [0.73316549 0.26683451]
# Expected Utility: [ 0.         -0.51207409]
# New Policy: [0.73577983 0.26422017]
# --------------------------------
# Difference: 0.005228683814140878
# Guess: [0.73342692 0.26657308]
# Expected Utility: [ 0.         -0.51221846]
# New Policy: [0.73583596 0.26416404]
# --------------------------------
# Difference: 0.004818074666232464
# Guess: [0.73366782 0.26633218]
# Expected Utility: [ 0.         -0.51235137]
# New Policy: [0.73588762 0.26411238]
# --------------------------------
# Difference: 0.0044395997692034395
# Guess: [0.7338898 0.2661102]
# Expected Utility: [ 0.         -0.51247373]
# New Policy: [0.73593518 0.26406482]
# --------------------------------
# Difference: 0.004090761103416496
# Guess: [0.73409434 0.26590566]
# Expected Utility: [ 0.         -0.51258639]
# New Policy: [0.73597897 0.26402103]
# --------------------------------
# Difference: 0.0037692522868877365
# Guess: [0.7342828 0.2657172]
# Expected Utility: [ 0.         -0.51269011]
# New Policy: [0.73601928 0.26398072]
# --------------------------------
# Difference: 0.003472944262625066
# Guess: [0.73445645 0.26554355]
# Expected Utility: [ 0.         -0.51278562]
# New Policy: [0.73605639 0.26394361]
# --------------------------------
# Difference: 0.003199871994994441
# Guess: [0.73461645 0.26538355]
# Expected Utility: [ 0.         -0.51287356]
# New Policy: [0.73609056 0.26390944]
# --------------------------------
# Difference: 0.0029482221134267683
# Guess: [0.73476386 0.26523614]
# Expected Utility: [ 0.         -0.51295454]
# New Policy: [0.73612202 0.26387798]
# --------------------------------
# Difference: 0.0027163214439748784
# Guess: [0.73489967 0.26510033]
# Expected Utility: [ 0.         -0.51302911]
# New Policy: [0.73615099 0.26384901]
# --------------------------------
# Difference: 0.002502626371655159
# Guess: [0.7350248 0.2649752]
# Expected Utility: [ 0.         -0.51309778]
# New Policy: [0.73617766 0.26382234]
# --------------------------------
# Difference: 0.0023057129790785558
# Guess: [0.73514009 0.26485991]
# Expected Utility: [ 0.         -0.51316101]
# New Policy: [0.73620222 0.26379778]
# --------------------------------
# Difference: 0.0021242679095269112
# Guess: [0.7352463 0.2647537]
# Expected Utility: [ 0.         -0.51321925]
# New Policy: [0.73622484 0.26377516]
# --------------------------------
# Difference: 0.0019570799053165167
# Guess: [0.73534416 0.26465584]
# Expected Utility: [ 0.         -0.51327288]
# New Policy: [0.73624567 0.26375433]
# --------------------------------
# Difference: 0.0018030319749766655
# Guess: [0.73543431 0.26456569]
# Expected Utility: [ 0.         -0.51332228]
# New Policy: [0.73626486 0.26373514]
# --------------------------------
# Difference: 0.0016610941454209827
# Guess: [0.73551736 0.26448264]
# Expected Utility: [ 0.         -0.51336777]
# New Policy: [0.73628252 0.26371748]
# --------------------------------
# Difference: 0.0015303167578790688
# Guess: [0.73559388 0.26440612]
# Expected Utility: [ 0.         -0.51340966]
# New Policy: [0.73629879 0.26370121]
# --------------------------------
# Difference: 0.00140982426887859
# Guess: [0.73566437 0.26433563]
# Expected Utility: [ 0.         -0.51344825]
# New Policy: [0.73631377 0.26368623]
# --------------------------------
# Difference: 0.0012988095199867877
# Guess: [0.73572931 0.26427069]
# Expected Utility: [ 0.         -0.51348379]
# New Policy: [0.73632757 0.26367243]
# --------------------------------
# Difference: 0.001196528442364564
# Guess: [0.73578914 0.26421086]
# Expected Utility: [ 0.         -0.51351652]
# New Policy: [0.73634028 0.26365972]
# --------------------------------
# Difference: 0.0011022951643943069
# Guess: [0.73584425 0.26415575]
# Expected Utility: [ 0.         -0.51354667]
# New Policy: [0.73635199 0.26364801]
# --------------------------------
# Difference: 0.0010154774927793042
# Guess: [0.73589503 0.26410497]
# Expected Utility: [ 0.         -0.51357444]
# New Policy: [0.73636277 0.26363723]
# --------------------------------
# Difference: 0.0009354927395052726
# Guess: [0.7359418 0.2640582]
# Expected Utility: [ 0.         -0.51360001]
# New Policy: [0.7363727 0.2636273]
# --------------------------------
# Difference: 0.0008618038689662266
# Guess: [0.73598489 0.26401511]
# Expected Utility: [ 0.         -0.51362357]
# New Policy: [0.73638185 0.26361815]
# --------------------------------
# Difference: 0.0007939159413370978
# Guess: [0.73602459 0.26397541]
# Expected Utility: [ 0.         -0.51364527]
# New Policy: [0.73639027 0.26360973]
# --------------------------------
# Difference: 0.0007313728299714328
# Guess: [0.73606115 0.26393885]
# Expected Utility: [ 0.         -0.51366525]
# New Policy: [0.73639803 0.26360197]
# --------------------------------
# Difference: 0.0006737541921754686
# Guess: [0.73609484 0.26390516]
# Expected Utility: [ 0.         -0.51368366]
# New Policy: [0.73640518 0.26359482]
# --------------------------------
# Difference: 0.0006206726741991297
# Guess: [0.73612588 0.26387412]
# Expected Utility: [ 0.         -0.51370062]
# New Policy: [0.73641176 0.26358824]
# --------------------------------
# Difference: 0.0005717713326703899
# Guess: [0.73615446 0.26384554]
# Expected Utility: [ 0.         -0.51371624]
# New Policy: [0.73641783 0.26358217]
# --------------------------------
# Difference: 0.0005267212559966761
# Guess: [0.7361808 0.2638192]
# Expected Utility: [ 0.         -0.51373063]
# New Policy: [0.73642341 0.26357659]
# --------------------------------
# Difference: 0.0004852193704664165
# Guess: [0.73620506 0.26379494]
# Expected Utility: [ 0.         -0.51374388]
# New Policy: [0.73642855 0.26357145]
# --------------------------------
# Difference: 0.00044698641691631735
# Guess: [0.73622741 0.26377259]
# Expected Utility: [ 0.         -0.51375608]
# New Policy: [0.73643329 0.26356671]
# --------------------------------
# Difference: 0.0004117650848726173
# Guess: [0.736248 0.263752]
# Expected Utility: [ 0.         -0.51376733]
# New Policy: [0.73643766 0.26356234]
# --------------------------------
# Difference: 0.00037931829206283574
# Guess: [0.73626697 0.26373303]
# Expected Utility: [ 0.         -0.51377769]
# New Policy: [0.73644168 0.26355832]
# --------------------------------
# Difference: 0.00034942759809231116
# Guess: [0.73628444 0.26371556]
# Expected Utility: [ 0.         -0.51378723]
# New Policy: [0.73644538 0.26355462]
# --------------------------------
# Difference: 0.0003218917419335887
# Guess: [0.73630053 0.26369947]
# Expected Utility: [ 0.         -0.51379601]
# New Policy: [0.73644879 0.26355121]
# --------------------------------
# Difference: 0.00029652529365004066
# Guess: [0.73631536 0.26368464]
# Expected Utility: [ 0.         -0.51380411]
# New Policy: [0.73645194 0.26354806]
# --------------------------------
# Difference: 0.00027315741151218154
# Guess: [0.73632902 0.26367098]
# Expected Utility: [ 0.         -0.51381157]
# New Policy: [0.73645483 0.26354517]
# --------------------------------
# Difference: 0.00025163069632849755
# Guess: [0.7363416 0.2636584]
# Expected Utility: [ 0.         -0.51381843]
# New Policy: [0.7364575 0.2635425]
# --------------------------------
# Difference: 0.0002318001354460475
# Guess: [0.73635319 0.26364681]
# Expected Utility: [ 0.         -0.51382476]
# New Policy: [0.73645995 0.26354005]
# --------------------------------
# Difference: 0.00021353212944469346
# Guess: [0.73636386 0.26363614]
# Expected Utility: [ 0.         -0.51383059]
# New Policy: [0.73646222 0.26353778]
# --------------------------------
# Difference: 0.0001967035950925511
# Guess: [0.7363737 0.2636263]
# Expected Utility: [ 0.         -0.51383596]
# New Policy: [0.7364643 0.2635357]
# --------------------------------
# Difference: 0.00018120113861858078
# Guess: [0.73638276 0.26361724]
# Expected Utility: [ 0.        -0.5138409]
# New Policy: [0.73646622 0.26353378]
# --------------------------------
# Difference: 0.0001669202938195946
# Guess: [0.7363911 0.2636089]
# Expected Utility: [ 0.         -0.51384546]
# New Policy: [0.73646799 0.26353201]
# --------------------------------
# Difference: 0.00015376481994061608
# Guess: [0.73639879 0.26360121]
# Expected Utility: [ 0.         -0.51384965]
# New Policy: [0.73646962 0.26353038]
# --------------------------------
# Difference: 0.00014164605466127078
# Guess: [0.73640588 0.26359412]
# Expected Utility: [ 0.         -0.51385352]
# New Policy: [0.73647112 0.26352888]
# --------------------------------
# Difference: 0.00013048231787715636
# Guess: [0.7364124 0.2635876]
# Expected Utility: [ 0.         -0.51385708]
# New Policy: [0.7364725 0.2635275]
# --------------------------------
# Difference: 0.00012019836230736658
# Guess: [0.73641841 0.26358159]
# Expected Utility: [ 0.         -0.51386036]
# New Policy: [0.73647377 0.26352623]
# --------------------------------
# Difference: 0.00011072486726027009
# Guess: [0.73642395 0.26357605]
# Expected Utility: [ 0.         -0.51386338]
# New Policy: [0.73647494 0.26352506]
# --------------------------------
# Difference: 0.00010199797217735895
# Guess: [0.73642905 0.26357095]
# Expected Utility: [ 0.         -0.51386617]
# New Policy: [0.73647602 0.26352398]
# QRE:  [0.73647602 0.26352398]
