# %%
import numpy as np
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import copy
import os
import random
import math as math
import matplotlib.pylab as plt #Typically matplotlib.pylab is imported as plt (shortened name)
import pdb
from scipy.optimize import minimize
import shutil
import csv
from MyLatexFunctions_SocialLearning import * 
from itertools import permutations 
from itertools import combinations
import csv


import networkx as nx

# %%
datafolder = "C:\\Users\\xinxi\\Purdue\\EffectiveSocialLearningProject\\DataAnalysis\\ImportedData\\"

# %%
 data = pd.read_csv(datafolder+"p_history.csv", sep=",", header=0)

# %%
data['last_infor_content'] = ""
data['num_red'] = 0
data['num_blue'] = 0

# %%
for i in range(len(data['p_history'])):
    
    data['last_infor_content'][i] =  data['p_history'][i].split("[[")[1].split("{")[-1].split("},")[0]
    red = 0
    blue = 0
    for x in data['last_infor_content'][i].split(":"):
        if "red" in x :
            red += 1
        if "blue" in x :
            blue += 1
    data['num_red'][i] = red
    data['num_blue'][i] = blue
# Out:
# C:\Users\xinxi\AppData\Local\Temp/ipykernel_8124/2680513950.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['last_infor_content'][i] =  data['p_history'][i].split("[[")[1].split("{")[-1].split("},")[0]
# C:\Users\xinxi\AppData\Local\Temp/ipykernel_8124/2680513950.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['num_red'][i] = red
# C:\Users\xinxi\AppData\Local\Temp/ipykernel_8124/2680513950.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
data.to_csv(datafolder+"p_history_changed.csv", sep=",")

# %%
data
# Out:
#      treatment waiting_cost  subject_id  round_id  \
# 0          a L            L           1        17
# 1          a L            L           1        18
# 2          a L            L           1        19
# 3          a L            L           1        20
# 4          a L            L           1        37
# ...        ...          ...         ...       ...
# 3995       b L            L          99        26
# 3996       b L            L          99        27
# 3997       b L            L          99        28
# 3998       b L            L          99        29
# 3999       b L            L          99        30
#
#                                               p_history  \
# 0     [[1, 1, {'D': 'blue', 'A': 'blue'}, 'Blue', 'B...
# 1     [[1, 1, {'D': 'blue', 'A': 'blue'}, 'Blue', 'B...
# 2     [[1, 1, {'D': 'blue', 'A': 'blue'}, 'Blue', 'B...
# 3     [[1, 1, {'D': 'blue', 'A': 'blue'}, 'Blue', 'B...
# 4     [[1, 2, {'D': 'blue', 'E': 'red', 'A': 'red'},...
# ...
